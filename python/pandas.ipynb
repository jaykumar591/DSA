# %%
import pandas as pd 
import matplotlib as mb 
data = pd.read_csv('./Crop_recommendation.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 import matplotlib as mb
#       3 data = pd.read_csv('./Crop_recommendation.csv')
# ----> 4 mb.color_sequences.get(data["temperature"])
#
# File <frozen _collections_abc>:807, in get(self, key, default)
#
# File c:\Python312\Lib\site-packages\matplotlib\colors.py:139, in ColorSequenceRegistry.__getitem__(self, item)
#     137 def __getitem__(self, item):
#     138     try:
# --> 139         return list(self._color_sequences[item])
#     140     except KeyError:
#     141         raise KeyError(f"{item!r} is not a known color sequence name")
#
# TypeError: unhashable type: 'Series'

# %%
# !pip install ipympl
# Out:
# Collecting ipympl
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python312\\etc'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting ipython-genutils (from ipympl)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: ipython<9 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipympl) (8.28.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\python312\lib\site-packages (from ipympl) (3.9.2)
# Requirement already satisfied: numpy in c:\python312\lib\site-packages (from ipympl) (2.1.1)
# Requirement already satisfied: pillow in c:\python312\lib\site-packages (from ipympl) (11.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: colorama in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets<9,>=7.6.0->ipympl)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets<9,>=7.6.0->ipympl)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from matplotlib<4,>=3.4.0->ipympl) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python312\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: wcwidth in c:\python312\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from stack-data->ipython<9->ipympl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jayku\appdata\roaming\python\python312\site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\jayku\appdata\roaming\python\python312\site-packages (from stack-data->ipython<9->ipympl) (0.2.3)
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
#    ---------------------------------------- 0.0/516.3 kB ? eta -:--:--
#    --- ------------------------------------ 41.0/516.3 kB 2.0 MB/s eta 0:00:01
#    --- ------------------------------------ 41.0/516.3 kB 2.0 MB/s eta 0:00:01
#    --- ------------------------------------ 41.0/516.3 kB 2.0 MB/s eta 0:00:01
#    --- ------------------------------------ 41.0/516.3 kB 2.0 MB/s eta 0:00:01
#    --- ------------------------------------ 41.0/516.3 kB 2.0 MB/s eta 0:00:01
#    --- ----------------------------------- 51.2/516.3 kB 175.0 kB/s eta 0:00:03
#    --- ----------------------------------- 51.2/516.3 kB 175.0 kB/s eta 0:00:03
#    ----- --------------------------------- 71.7/516.3 kB 179.1 kB/s eta 0:00:03
#    ----- --------------------------------- 71.7/516.3 kB 179.1 kB/s eta 0:00:03
#    ----- --------------------------------- 71.7/516.3 kB 179.1 kB/s eta 0:00:03
#    ------ -------------------------------- 81.9/516.3 kB 153.2 kB/s eta 0:00:03
#    ----------- -------------------------- 153.6/516.3 kB 255.1 kB/s eta 0:00:02
#    ------------ ------------------------- 163.8/516.3 kB 273.3 kB/s eta 0:00:02
#    ------------ ------------------------- 163.8/516.3 kB 273.3 kB/s eta 0:00:02
#    ------------ ------------------------- 163.8/516.3 kB 273.3 kB/s eta 0:00:02
#    --------------- ---------------------- 204.8/516.3 kB 265.1 kB/s eta 0:00:02
#    ------------------ ------------------- 245.8/516.3 kB 301.6 kB/s eta 0:00:01
#    ------------------- ------------------ 266.2/516.3 kB 321.2 kB/s eta 0:00:01
#    ----------------------- -------------- 317.4/516.3 kB 351.1 kB/s eta 0:00:01
#    ----------------------- -------------- 317.4/516.3 kB 351.1 kB/s eta 0:00:01
#    ------------------------ ------------- 327.7/516.3 kB 327.9 kB/s eta 0:00:01
#    ------------------------------ ------- 409.6/516.3 kB 387.4 kB/s eta 0:00:01
#    ------------------------------------ - 491.5/516.3 kB 453.2 kB/s eta 0:00:01
#    -------------------------------------- 516.3/516.3 kB 456.3 kB/s eta 0:00:00
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Installing collected packages: ipython-genutils, widgetsnbextension, jupyterlab-widgets, ipywidgets, ipympl

# %%
import matplotlib
import matplotlib.pyplot as plt

print(matplotlib.get_backend())
plt.plot((5, 4100, 6))
plt.show()
# Out:
# module://matplotlib_inline.backend_inline

# %%
 import matplotlib
 import pandas as pd 
 import matplotlib.pyplot as pyt 
 
 data = pd.read_csv('./Crop_recommendation.csv')
 print(matplotlib.get_backend())
 
 pyt.plot(data["temperature"])
 pyt.bar(data["humidity"],100,1,10)
 pyt.draw()
 pyt.bar(data['temperature'],300,5,4)
 pyt.show()
# Out:
# module://matplotlib_inline.backend_inline
